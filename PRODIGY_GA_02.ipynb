# %% [markdown]
# # 🌟 **Internship Task 2 at Prodigy Infotec: Generative AI Intern**

# %% [markdown]
# ## 🎨 **Image Generation with Pre-trained Models**
#
# ### 🎯 **Task 2  Overview:**
# In this project, you will utilize pre-trained **generative models** like **DALL-E mini** or **Stable Diffusion** to create images from text prompts. These models are capable of generating realistic or artistic images based on textual descriptions, leveraging large-scale training data.
#
# The task is to experiment with these models to create images that match specific text descriptions, exploring how text can be transformed into visual content using generative AI techniques.
#
# ---
#
# ### 🛠️ **How You’ll Achieve This:**
#
# 1. **Understand the Generative Models:**
#    - **DALL-E mini** and **Stable Diffusion** are both pre-trained models designed to generate images from textual descriptions. They use large datasets and advanced machine learning techniques to understand how text correlates with visual elements.
#    - **DALL-E mini** is a smaller, faster version of the original DALL-E model, ideal for generating diverse images from short text prompts.
#    - **Stable Diffusion** is known for producing high-quality images by iterating over several stages, refining the image output progressively.
#
# 2. **Set Up the Environment:**
#    - Install the necessary libraries and models. For example, you may need to use the **Hugging Face Transformers library** or access the models directly from services like **Hugging Face** or **Replicate**.
#    - Set up **Python** environments and dependencies (e.g., `torch`, `transformers`, `diffusers`, etc.).
#
# 3. **Pre-trained Model Access:**
#    - You will access the pre-trained models through APIs or by running them locally (if your system supports it).
#    - You can use an API from platforms like **Hugging Face** to easily connect to the models and generate images from text prompts.
#
# 4. **Prepare Text Prompts:**
#    - Formulate clear and detailed **text prompts** that describe the images you want to generate. For example:
#      - "A futuristic city skyline at sunset."
#      - "A majestic lion resting in the grass."
#    - The more specific and descriptive your prompt is, the better the model will generate the desired image.
#
# 5. **Generate the Image:**
#    - Input your text prompts into the pre-trained model and use the model’s API or library functions to generate the image.
#    - Depending on the model, this process might take a few seconds to several minutes, depending on the complexity and resolution of the image.
#
# 6. **Fine-tune the Output (Optional):**
#    - Experiment with different prompts to refine the output. If necessary, adjust the prompts slightly to get the desired image style, color scheme, or composition.
#    - You can also tweak additional parameters like **resolution** or **creativity** settings to customize the generated results.
#
# 7. **Evaluate the Generated Image:**
#    - After generating the image, assess how well it matches your expectations based on the text prompt.
#    - Evaluate the quality of the image in terms of realism, coherence with the prompt, and artistic style.
#
# ---
#
# ### 🚀 **Outcome:**
#
# By the end of this project, you will have:
# - Gained hands-on experience with **pre-trained generative models** like DALL-E mini and Stable Diffusion.
# - Learned how to generate high-quality images from text prompts.
# - Explored the possibilities of **text-to-image generation**, a crucial application in the field of **Generative AI**.
#
# This project provides a great introduction to the power of **text-to-image synthesis**, showcasing how AI can turn creative ideas into visual representations.

# %% [markdown]
# # 🚀 Installing OpenAI Python Package
#
# ### Steps:
# 1. 📥 **Install the OpenAI package**
#    - Run the command:
#      `!pip install openai`
#      - This will install the OpenAI Python library.
#
# 2. 🔄 **Wait for Installation**
#    - The package will be downloaded and installed in your environment.
#
# 3. ✅ **Ready to Use**
#    - After installation, you can use OpenAI's API in your Python code for various tasks, like GPT models, DALL·E, etc.

# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# # 🛠️ Importing OpenAI Python Library
#
# ### Steps:
# 1. 📚 **Import the OpenAI Module**
#    - Run the command:
#      `from openai import OpenAI`
#      - This imports the OpenAI module to use its functions in your code.
#
# 2. 🔍 **Check for Errors**
#    - If there’s no error, the OpenAI library is successfully imported.
#
# 3. 🔓 **Access OpenAI's Features**
#    - Now you can access OpenAI's models and features such as GPT-3, DALL·E, and others for text generation, image generation, etc.

# %%
from openai import OpenAI

# %% [markdown]
# ## 🔑 Loading OpenAI API Key and Creating a Client
#
# ### Steps:
# 1. 📂 **Open the API Key File**
#    - Reads the API key stored in a text file.
#
# 2. 🔑 **Read the API Key**
#    - Extracts the key and stores it in a variable.
#
# 3. 🤖 **Initialize OpenAI Client**
#    - Uses the API key to authenticate and create an OpenAI client.
#
# 4. ✅ **Ready to Use**
#    - The client is set up for making API requests like text and image generation.

# %%
f = open(r"C:\Users\mdimr\OneDrive\Documents\Open Api Keys\Gen ai key.txt")
OPENAI_API_KEY = f.read()

client = OpenAI(api_key = OPENAI_API_KEY)

# %% [markdown]
# ## 🖼️ Generating an AI-Generated Image with OpenAI
#
# ### Steps:
# 1. 📦 **Import Necessary Libraries**
#    - Loads OpenAI, requests, and PIL for handling image generation and display.
#
# 2. 🤖 **Request Image Generation**
#    - Sends a prompt to OpenAI’s DALL·E-2 model to generate an image of a futuristic city with flying cars.
#
# 3. 🌐 **Retrieve Image URL**
#    - The API returns a URL containing the generated image.
#
# 4. 🔗 **Display or Download the Image**
#    - Prints the image URL for access or further processing.

# %%
import openai
import requests
from PIL import Image
from io import BytesIO

response = client.images.generate(
  model="dall-e-2",
  prompt="A futuristic city with flying cars",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lJFHttTcL8KQsrWnHCbzJJ6J/user-mYSlwT6zCF6yaWxs6v2WLSCz/img-Lr5vXv90ekiL4Nkg7Z1kyFBJ.png?st=2025-02-05T08%3A44%3A48Z&se=2025-02-05T10%3A44%3A48Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-05T00%3A32%3A12Z&ske=2025-02-06T00%3A32%3A12Z&sks=b&skv=2024-08-04&sig=bMzcYsCQAwWqn4AIC0xnvzLNfZskru4qQ2zNgb3q7Cw%3D

# %% [markdown]
# ## 🖼️ Displaying an AI-Generated Image
#
# ### Steps:
# 1. 📦 **Import Required Libraries**
#    - Uses Matplotlib for visualization, PIL for image processing, and Requests for fetching the image.
#
# 2. 🌐 **Fetch Image from URL**
#    - Downloads the image from the provided URL.
#
# 3. 🖼️ **Open the Image**
#    - Converts the downloaded content into an image format.
#
# 4. 📊 **Display the Image**
#    - Uses Matplotlib to render and show the generated image.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

def image_from_url(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    return img

img = image_from_url(image_url)
plt.imshow(img)

# %% [markdown]
# ## Creating another image  url

# %%
import openai
import requests
from PIL import Image
from io import BytesIO

response = client.images.generate(
  model="dall-e-2",
  prompt="A beautiful girl dancing with peacock",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lJFHttTcL8KQsrWnHCbzJJ6J/user-mYSlwT6zCF6yaWxs6v2WLSCz/img-AZ9pEn8RpNwNp3JS9cEhvPdW.png?st=2025-02-05T08%3A46%3A25Z&se=2025-02-05T10%3A46%3A25Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-05T00%3A23%3A28Z&ske=2025-02-06T00%3A23%3A28Z&sks=b&skv=2024-08-04&sig=VhFW79dXSC0VwjOClnA73KLECbByqx8D6F08OWozXTc%3D

# %% [markdown]
# ## 🖼️ Displaying an AI-Generated Image

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

def image_from_url(image_url):
    img = Image.open(requests.get(image_url, stream=True).raw)
    return img

img = image_from_url(image_url)
plt.imshow(img)
